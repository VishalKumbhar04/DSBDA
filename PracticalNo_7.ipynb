# %%
import nltk

# %%
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('average_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Error loading average_perceptron_tagger: Package
# [nltk_data]     'average_perceptron_tagger' not found in index
# False

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = """Tokenization is the first step in text analytics. 
The process of breaking down a text paragraph into smaller chunks 
such as words or sentences is called Tokenization."""

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
sentences = sent_tokenize(text)
print("Sentence Tokenization:\n", sentences)
# Out:
# Sentence Tokenization:
#  ['Tokenization is the first step in text analytics.', 'The process of breaking down a text paragraph into smaller chunks \nsuch as words or sentences is called Tokenization.']

# %%
words = word_tokenize(text)
print("\nWord Tokenization:\n", words)
# Out:
# Word Tokenization:
#  ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))

# %%
clean_text = re.sub('[^a-zA-Z]', ' ', text)

# %%
tokens = word_tokenize(clean_text.lower())

# %%
filtered_words = [w for w in tokens if w not in stop_words]
print("\nFiltered Words:\n", filtered_words)
# Out:
# Filtered Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunks', 'words', 'sentences', 'called', 'tokenization']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
stemmed_words = [ps.stem(w) for w in filtered_words]
print("\nStemmed Words:\n", stemmed_words)
# Out:
# Stemmed Words:
#  ['token', 'first', 'step', 'text', 'analyt', 'process', 'break', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentenc', 'call', 'token']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(w) for w in filtered_words]
print("\nLemmatized Words:\n", lemmatized_words)
# Out:
# Lemmatized Words:
#  ['tokenization', 'first', 'step', 'text', 'analytics', 'process', 'breaking', 'text', 'paragraph', 'smaller', 'chunk', 'word', 'sentence', 'called', 'tokenization']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Vishal Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
pos_tags = nltk.pos_tag(filtered_words)
print("\nPOS Tagging:\n", pos_tags)
# Out:
# POS Tagging:
#  [('tokenization', 'NN'), ('first', 'RB'), ('step', 'VB'), ('text', 'JJ'), ('analytics', 'NNS'), ('process', 'NN'), ('breaking', 'VBG'), ('text', 'NN'), ('paragraph', 'NN'), ('smaller', 'JJR'), ('chunks', 'NNS'), ('words', 'NNS'), ('sentences', 'NNS'), ('called', 'VBD'), ('tokenization', 'NN')]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [documentA, documentB]

# %%
documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth planet from the Sun'

# %%
stop_words = set(stopwords.words('english'))

# %%
processed_docs = []
for doc in documents:
    doc = doc.lower()
    words = word_tokenize(doc)
    filtered_words = [w for w in words if w not in stop_words]
    processed_docs.append(filtered_words)
    print("Processed Documents:")
for i, doc in enumerate(processed_docs):
    print(f"Doc {i+1}: {doc}")
# Out:
# Processed Documents:
# Processed Documents:
# Doc 1: ['jupiter', 'largest', 'planet']
# Doc 2: ['mars', 'fourth', 'planet', 'sun']

# %%
vocab = set()
for doc in processed_docs:
    vocab.update(doc)
vocab = list(vocab)
print("\nVocabulary:", vocab)
# Out:
# Vocabulary: ['largest', 'jupiter', 'fourth', 'planet', 'mars', 'sun']

# %%
def compute_tf(doc):
    tf_dict = {}
    doc_len = len(doc)
    print("\nTF Calculation:")
    for word in vocab:
        count = doc.count(word)
        tf = count / doc_len
        tf_dict[word] = tf
        print(f"{word} = {count}/{doc_len} = {tf}")
    return tf_dict
tf_docs = []
for i, doc in enumerate(processed_docs):
    print(f"\n--- TF for Document {i+1} ---")
    tf_docs.append(compute_tf(doc))
# Out:
# --- TF for Document 1 ---
#
# TF Calculation:
# largest = 1/3 = 0.3333333333333333
# jupiter = 1/3 = 0.3333333333333333
# fourth = 0/3 = 0.0
# planet = 1/3 = 0.3333333333333333
# mars = 0/3 = 0.0
# sun = 0/3 = 0.0
#
# --- TF for Document 2 ---
#
# TF Calculation:
# largest = 0/4 = 0.0
# jupiter = 0/4 = 0.0
# fourth = 1/4 = 0.25
# planet = 1/4 = 0.25
# mars = 1/4 = 0.25
# sun = 1/4 = 0.25

# %%
docA = "this is a sample"
docB = "this is another example"

bagOfWordsA = docA.split()
bagOfWordsB = docB.split()

wordDictA = dict.fromkeys(bagOfWordsA, 0)
for word in bagOfWordsA:
    wordDictA[word] += 1

wordDictB = dict.fromkeys(bagOfWordsB, 0)
for word in bagOfWordsB:
    wordDictB[word] += 1

def computeTF(wordDict, bagOfWords):
    tfDict = {}
    totalWords = len(bagOfWords)
    
    for word, count in wordDict.items():
        tfDict[word] = count / float(totalWords)
    
    return tfDict

tfA = computeTF(wordDictA, bagOfWordsA)
tfB = computeTF(wordDictB, bagOfWordsB)

print(tfA)
print(tfB)
# Out:
# {'this': 0.25, 'is': 0.25, 'a': 0.25, 'sample': 0.25}
# {'this': 0.25, 'is': 0.25, 'another': 0.25, 'example': 0.25}

# %%
import math
def compute_idf(docs):
    N = len(docs)
    idf_dict = {}
    print("\nIDF Calculation:")
    for word in vocab:
        count = sum(1 for doc in docs if word in doc)
        idf = math.log(N / (count + 1)) + 1 # smoothing
        idf_dict[word] = idf
        print(f"{word} → appears in {count} docs → IDF = {idf}")
    return idf_dict
idf = compute_idf(processed_docs)
# Out:
# IDF Calculation:
# largest → appears in 1 docs → IDF = 1.0
# jupiter → appears in 1 docs → IDF = 1.0
# fourth → appears in 1 docs → IDF = 1.0
# planet → appears in 2 docs → IDF = 0.5945348918918356
# mars → appears in 1 docs → IDF = 1.0
# sun → appears in 1 docs → IDF = 1.0

# %%
def compute_tfidf(tf, idf):
    tfidf = {}
    for word in vocab:
        tfidf[word] = tf[word] * idf[word]
    return tfidf
tfidf_docs = []

# %%
for i, tf in enumerate(tf_docs):
    tfidf_docs.append(compute_tfidf(tf, idf))
print("\nTF-IDF Results:")
for i, tfidf in enumerate(tfidf_docs):
    print(f"\nDocument {i+1}:")
    for word, value in tfidf.items():
        print(f"{word}: {value}")
# Out:
# TF-IDF Results:
#
# Document 1:
# largest: 0.3333333333333333
# jupiter: 0.3333333333333333
# fourth: 0.0
# planet: 0.19817829729727854
# mars: 0.0
# sun: 0.0
#
# Document 2:
# largest: 0.0
# jupiter: 0.0
# fourth: 0.25
# planet: 0.1486337229729589
# mars: 0.25
# sun: 0.25
