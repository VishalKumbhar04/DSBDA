# %%
import pandas as pd

# %%
import numpy as np

# %%
 import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\DSBDA\Practicals\Pandas\StudPerf_Dataset.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 0         74.0           86.0           73.0             83.0       2023
# 1         77.0           90.0           72.0             75.0       2020
# 2         77.0           81.0           79.0             85.0       2022
# 3         94.0           85.0           72.0             84.0       2023
# 4         66.0           87.0           68.0             96.0       2022
# ..         ...            ...            ...              ...        ...
# 84        64.0            NaN           67.0              NaN       2022
# 85        70.0           83.0           66.0             97.0       2024
# 86        70.0           81.0           69.0             90.0       2023
# 87        77.0           99.0           66.0             95.0       2020
# 88        74.0           80.0           74.0             95.0       2022
#
#     Placement_Offer
# 0               2.0
# 1               2.0
# 2               3.0
# ...

# %%
col = ['Math_Score','Reading_Score','Writing_Score','Placement_Offer']

# %%
df.boxplot(col)
plt.show()

# %%
print(np.where(df['Reading_Score']>90))
# Out:
# (array([52, 87]),)

# %%
print(np.where(df['Writing_Score']<25))
# Out:
# (array([61]),)

# %%
print(np.where(df['Math_Score']<30))
# Out:
# (array([19]),)

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\DSBDA\Practicals\Pandas\StudPerf_Dataset.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join  \
# 0         74.0           86.0           73.0             83.0       2023
# 1         77.0           90.0           72.0             75.0       2020
# 2         77.0           81.0           79.0             85.0       2022
# 3         94.0           85.0           72.0             84.0       2023
# 4         66.0           87.0           68.0             96.0       2022
# ..         ...            ...            ...              ...        ...
# 84        64.0            NaN           67.0              NaN       2022
# 85        70.0           83.0           66.0             97.0       2024
# 86        70.0           81.0           69.0             90.0       2023
# 87        77.0           99.0           66.0             95.0       2020
# 88        74.0           80.0           74.0             95.0       2022
#
#     Placement_Offer
# 0               2.0
# 1               2.0
# 2               3.0
# ...

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Placement_Score'], df['Placement_Offer'])
plt.show()

# %%
print(np.where((df['Placement_Score']<50) & (df['Placement_Offer']>1)))
print(np.where)
# Out:
# (array([], dtype=int64),)
# <built-in function where>

# %%
print(np.where((df['Placement_Score']>85) & (df['Placement_Offer']<3)))
# Out:
# (array([ 6, 15, 86]),)

# %%
import numpy as np

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['Math_Score']))

# %%
print(z)
# Out:
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([], dtype=int64),)

# %%
import numpy as np

# %%
sorted_rscore= sorted(df['Reading_Score'])

# %%
sorted_rscore
# Out:
# [0.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  90.0,
#  90.0,
#  99.0,
#  100.0,
#  nan]

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)

# %%
sample_outliers
# Out:
# (array([], dtype=int64),)

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# nan nan

# %%
import numpy as np

# %%
sorted_rscore= sorted(df['Reading_Score'])

# %%
sorted_rscore
# Out:
# [0.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  90.0,
#  90.0,
#  99.0,
#  100.0,
#  nan]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)

# %%
print(q1,q3)
# Out:
# nan nan

# %%
sorted_rscore
# Out:
# [0.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  90.0,
#  90.0,
#  99.0,
#  100.0,
#  nan]

# %%
df=pd.read_csv("C:\DSBDA\Practicals\Pandas\StudPerf_Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       85 non-null     float64
#  1   Reading_Score    88 non-null     float64
#  2   Writing_Score    86 non-null     float64
#  3   Placement_Score  87 non-null     float64
#  4   Club_Join        89 non-null     int64
#  5   Placement_Offer  86 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.3 KB

# %%
sorted_rscore= sorted(df['Reading_Score'])

# %%
sorted_rscore
# Out:
# [0.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  90.0,
#  90.0,
#  99.0,
#  100.0,
#  nan]

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)

# %%
upr_bound = q3+(1.5*IQR)

# %%
print(lwr_bound, upr_bound)
# Out:
# nan nan

# %%
r_outliers = []

# %%
r_outliers = []

for i in sorted_rscore:
    if i < lwr_bound or i > upr_bound:
        r_outliers.append(i)

# %%
print(r_outliers)
# Out:
# []

# %%
df=pd.read_csv("C:\DSBDA\Practicals\Pandas\StudPerf_Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math_Score       85 non-null     float64
#  1   Reading_Score    88 non-null     float64
#  2   Writing_Score    86 non-null     float64
#  3   Placement_Score  87 non-null     float64
#  4   Club_Join        89 non-null     int64
#  5   Placement_Offer  86 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.3 KB

# %%
sorted_rscore= sorted(df['Reading_Score'])

# %%
sorted_rscore
# Out:
# [0.0,
#  75.0,
#  75.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  81.0,
#  82.0,
#  82.0,
#  82.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  83.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  84.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  85.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  86.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  87.0,
#  88.0,
#  88.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  89.0,
#  90.0,
#  90.0,
#  90.0,
#  90.0,
#  99.0,
#  100.0,
#  nan]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)

# %%
print(q1,q3)
# Out:
# nan nan

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)

# %%
upr_bound = q3+(1.5*IQR)

# %%
print(lwr_bound, upr_bound)
# Out:
# nan nan

# %%
r_outliers = []

for i in sorted_rscore:
    if i < lwr_bound or i > upr_bound:
        r_outliers.append(i)

# %%
print(r_outliers)
# Out:
# []

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (18,10))
