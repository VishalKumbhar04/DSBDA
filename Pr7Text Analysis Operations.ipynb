# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Vishal Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Vishal
# [nltk_data]     Kumbhar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
import math
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Sample documents
documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth planet from the Sun'

# %%
documents = [documentA, documentB]

# %%
# Load stopwords
stop_words = set(stopwords.words('english'))

# Step 1: Preprocessing (lowercase + tokenization + stopword removal)
processed_docs = []

for doc in documents:
    doc = doc.lower()
    words = word_tokenize(doc)
    filtered_words = [w for w in words if w not in stop_words]
    processed_docs.append(filtered_words)

print("Processed Documents:", processed_docs)
# Out:
# Processed Documents: [['jupiter', 'largest', 'planet'], ['mars', 'fourth', 'planet', 'sun']]

# %%
# Step 2: Vocabulary
vocab = set()
for doc in processed_docs:
    vocab.update(doc)

vocab = list(vocab)

# %%
# Step 3: Term Frequency (TF)
def compute_tf(doc):
    tf_dict = {}
    doc_len = len(doc)
    for word in vocab:
        tf_dict[word] = doc.count(word) / doc_len
    return tf_dict

tf_docs = [compute_tf(doc) for doc in processed_docs]

# %%
# Step 4: Inverse Document Frequency (IDF)
def compute_idf(docs):
    N = len(docs)
    idf_dict = {}

    for word in vocab:
        count = sum(1 for doc in docs if word in doc)
        idf_dict[word] = math.log(N / (count + 1)) + 1  # smoothing

    return idf_dict

idf = compute_idf(processed_docs)

# %%
# Step 5: TF-IDF
def compute_tfidf(tf, idf):
    tfidf = {}
    for word in vocab:
        tfidf[word] = tf[word] * idf[word]
    return tfidf

tfidf_docs = [compute_tfidf(tf, idf) for tf in tf_docs]

# %%
# Output
print("\nVocabulary:", vocab)

print("\nTF for each document:")
for i, tf in enumerate(tf_docs):
    print(f"Document {i+1}:", tf)

print("\nIDF values:")
print(idf)
print("\nTF-IDF for each document:")
for i, tfidf in enumerate(tfidf_docs):
    print(f"Document {i+1}:", tfidf)
# Out:
# Vocabulary: ['fourth', 'planet', 'sun', 'jupiter', 'mars', 'largest']
#
# TF for each document:
# Document 1: {'fourth': 0.0, 'planet': 0.3333333333333333, 'sun': 0.0, 'jupiter': 0.3333333333333333, 'mars': 0.0, 'largest': 0.3333333333333333}
# Document 2: {'fourth': 0.25, 'planet': 0.25, 'sun': 0.25, 'jupiter': 0.0, 'mars': 0.25, 'largest': 0.0}
#
# IDF values:
# {'fourth': 1.0, 'planet': 0.5945348918918356, 'sun': 1.0, 'jupiter': 1.0, 'mars': 1.0, 'largest': 1.0}
#
# TF-IDF for each document:
# Document 1: {'fourth': 0.0, 'planet': 0.19817829729727854, 'sun': 0.0, 'jupiter': 0.3333333333333333, 'mars': 0.0, 'largest': 0.3333333333333333}
# Document 2: {'fourth': 0.25, 'planet': 0.1486337229729589, 'sun': 0.25, 'jupiter': 0.0, 'mars': 0.25, 'largest': 0.0}
